# %%
import pandas as pd
import numpy as np

# %%
# load the dataset
dataset = pd.read_csv('Computer-Hardware-Dataset-data-header.csv', header=0, index_col=0)

# %%
# split into input (X) and output (Y) variables
X_train = dataset[['MYCT','MMIN','MMAX','CACH','CHMIN','CHMAX','ERP']]
Y_train = dataset['PRP']

# %%
from sklearn.naive_bayes import GaussianNB

# %%
# create Gaussian Naive Bayes model object and train it with the data
nb_model = GaussianNB()

# %%
nb_model.fit(X_train, Y_train.ravel())
# Out:
# GaussianNB()

# %%
# predict values using the training data
nb_predict_train = nb_model.predict(X_train)

# %%
# import the performance metrics library
from sklearn import metrics

# %%
# Accuracy
print("Accuracy: {0:.4f}".format(metrics.accuracy_score(Y_train, nb_predict_train)))
print()
# Out:
# Accuracy: 0.6029

# %%
# import the lib to load / Save the model
import joblib

# %%
#joblib.dump(nb_predict_train, "trained-model.pkl")
joblib.dump(nb_model, "trained-model.pkl")
# Out:
# ['trained-model.pkl']

# %%
# import the lib to load / Save the model
import joblib

# %%
import numpy as np

# %%
# Load the model
nb_predict_train = joblib.load("trained-model.pkl")

# %%
# load the test dataset
dataset = pd.read_csv('Computer-Hardware-Dataset-data-header.csv', header=0, index_col=0)

# %%
X_train =dataset[['MYCT','MMIN','MMAX','CACH','CHMIN','CHMAX','ERP']]

# %%
nb_predict_train.predict(X_train)
# Out:
# array([ 198,  172,  172,  172,  132,  318,  367,  367,  636, 1144,   16,
#          27,   92,  138,   10,   35,   19,   28,   31,  120,   30,   33,
#          61,   76,   23,   69,   12,   18,   77,   27,  274,  274,   63,
#          63,  106,  208,   11,   29,   56,   29,   62,   52,   52,   52,
#          72,   72,   11,   16,   40,   62,   16,   12,  138,   62,   26,
#          60,   71,   14,   14,   14,   14,   14,   36,  144,  144,  259,
#          17,   17,   38,   52,   62,   64,   36,   36,   44,   50,   22,
#          53,   36,   84,   16,   38,   38,   16,   27,   29,   29,   52,
#         134,   70,  141,  141,   52,  132,  237,  465,  465,  277,  185,
#           6,   25,   26,    7,   13,   11,   24,   32,   11,   11,   18,
#          20,   37,   29,   29,   71,  138,  138,   27,   49,   52,  100,
#         133,   12,   18,   18,   29,   56,   56,   80,   80,  136,   62,
#          62,   62,   52,   54,   54,   30,   71,   29,   62,   62,   71,
# ...

# %%
print(X_train)
# Out:
#              MYCT  MMIN   MMAX  CACH  CHMIN  CHMAX  ERP
# Vendor Name
# adviser       125   256   6000   256     16    128  199
# amdahl         29  8000  32000    32      8     32  253
# amdahl         29  8000  32000    32      8     32  253
# amdahl         29  8000  32000    32      8     32  253
# amdahl         29  8000  16000    32      8     16  132
# ...           ...   ...    ...   ...    ...    ...  ...
# sperry        124  1000   8000     0      1      8   37
# sperry         98  1000   8000    32      2      8   50
# sratus        125  2000   8000     0      2     14   41
# wang          480   512   8000    32      0      0   47
# wang          480  1000   4000     0      0      0   25
#
# [209 rows x 7 columns]

# %%
# print predicted values
pred = nb_predict_train.predict(X_train)

# %%
print(pred)
# Out:
# [ 198  172  172  172  132  318  367  367  636 1144   16   27   92  138
#    10   35   19   28   31  120   30   33   61   76   23   69   12   18
#    77   27  274  274   63   63  106  208   11   29   56   29   62   52
#    52   52   72   72   11   16   40   62   16   12  138   62   26   60
#    71   14   14   14   14   14   36  144  144  259   17   17   38   52
#    62   64   36   36   44   50   22   53   36   84   16   38   38   16
#    27   29   29   52  134   70  141  141   52  132  237  465  465  277
#   185    6   25   26    7   13   11   24   32   11   11   18   20   37
#    29   29   71  138  138   27   49   52  100  133   12   18   18   29
#    56   56   80   80  136   62   62   62   52   54   54   30   71   29
#    62   62   71  138   86   74   93  111  143  105  132  277  370  510
#   214  326  510    8   17   21   21   62   42   42  138   51   51  100
#   140  212   25   25   41   25   27   38   27   36   38   62  109    6
# ...

# %%
dataset = pd.read_csv('Computer-Hardware-Dataset-data-header.csv', header=0, index_col=0)
concat_array = np.c_[dataset,pred]

# %%
# write it in a csv file
# np.to_csv('outputfile.csv',concat_array)

# %%
dataset.to_csv('output.csv')
